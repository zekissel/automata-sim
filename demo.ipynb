# %%
from builder import Builder

# %%
factory = Builder()
dfa = factory.parseDFA('models/dfa/dfa_config.xml')
factory.plot(dfa)
# Out:
# NFA strings ending in 01
# [s: 0; a: [2]]:
# {'id': 'q0', '0': 1, '1': 0}
# {'id': 'q1', '0': 1, '1': 2}
# {'id': 'q2', '0': 1, '1': 0}

# %%
gnfa = factory.generalize(dfa)

# %%
gnfa = factory.proceduralCollapse(gnfa)
# Out:
# GNFA strings ending in 01
# {'id': 's', ('s', 'q0'): 'e'}
# {'id': 'q0', ('q0', 'q1'): '0', ('q0', 'q0'): '1'}
# {'id': 'q1', ('q1', 'q1'): '0', ('q1', 'q2'): '1'}
# {'id': 'q2', ('q2', 'q1'): '0', ('q2', 'q0'): '1', ('q2', 'a'): 'e'}
# {'id': 'a'}
# GNFA strings ending in 01
# {'id': 's', ('s', 'q1'): '1*0'}
# {'id': 'q1', ('q1', 'q1'): '0', ('q1', 'q2'): '1'}
# {'id': 'q2', ('q2', 'q1'): '(11*0U0)', ('q2', 'a'): 'e'}
# {'id': 'a'}
# GNFA strings ending in 01
# {'id': 's', ('s', 'q2'): '1*00*1'}
# {'id': 'q2', ('q2', 'a'): 'e', ('q2', 'q2'): '(11*0U0)0*1'}
# {'id': 'a'}
# GNFA strings ending in 01
# {'id': 's', ('s', 'a'): '1*00*1((11*0U0)0*1)*'}
# {'id': 'a'}
