# %%
from nondetfinauto import NFA

# %%
nfa0 = NFA()
nfa0.parse_from_xml('models/nfa/nfa_config0.xml')
print(nfa0.__repr__())

print(nfa0.process_string('0'))
print(nfa0.process_string('1'))
nfa0.graph()
# Out:
# NFA (0)
# [s: 0; a: [1]]:
# {'id': 'q0', '0': [1], '1': [-1], 'e': [-1]}
# {'id': 'q1', '0': [-1], '1': [-1], 'e': [-1]}
# True
# False

# %%
nfa1 = NFA()
nfa1.parse_from_xml('models/nfa/nfa_config1.xml')
print(nfa1.__repr__())

print(nfa1.process_string('0'))
print(nfa1.process_string('1'))
nfa1.graph()
# Out:
# NFA (1)
# [s: 0; a: [1]]:
# {'id': 'q0', '0': [-1], '1': [1], 'e': [-1]}
# {'id': 'q1', '0': [-1], '1': [-1], 'e': [-1]}
# False
# True

# %%
nfa0.union(nfa1)
nfa0.star()
nfa0.graph()
